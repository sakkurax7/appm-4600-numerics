# %% [markdown]
# # Practice Midterm 2
#
# ## Problem 1
# ### Part a
# We have found the ONLY unique polynomial! If $p(x)$ and $q(x)$ are polynomials of degree $\leq n$, where $n=11$ is the number of datapoints, every degree $\leq 11$ polynomial is exactly the same.
#
# ### Part b
# This isn't great becuase if $n$ is large, the Vendermode matrix is very ill conditioned and is hard to invert. Further, adding a new datapoint will require recomputation of the entire matrix inverse which can be costly.
#
# ### Part c
# The barycentric version is faster for evaluation, requiring $\mathcal{O}(n)$ flops. However, both have the same build time of $\mathcal{O}(n^2)$.
#
# ### Part d
# Spline interpolants are much more general, they are just piecewise functions that agree on the datapoints. Hermite interpolants are more restrictive, requiring continuity at the derivatives as well (up to some number of derivatives).
#
# ### Part e
# The first set is preferable as it supresses the Runge phenomenon in all cases, regardless of the choice of basis. The second could be susceptible to these deviations at the endpoints for, say polynomials.
#
# ## Problem 2
# ### Part a
# $$E = || f- \sum_{j=0}^10 a_j x^j ||^2 $$
# Then minimize for each $k$
# $$\frac{\partial E}{\partial a_k} = 0 \implies $$\langle f - \sum_{j=0}^10 a_j x^j \rangle = 0$$ now $$\langle f, x^k \rangle = \sum a_j \langle x^j, x^k \rangle$$ which is $\frac{2}{j+k+1}$ if $j+k$ is even or 0 if odd. Then compute the gram matrix $G_{kj} = \langle x^j, x^k \rangle$ and $b_k = \langle f, x^k \rangle$ and solve $a = G^{-1}b$
#
# ### Part b
# Not really, this requires Hilbert space methods :)
#
# ### Part c
# Yes. Let $\phi_k = P_k$ Notice $$E^2=||f-\sum_{k=0}^N a_k \phi_k ||_{L^2}^2 = \langle f-\sum_{k=0}^N a_k \phi_k, f-\sum_{k=0}^N a_k \phi_k \rangle  = ||f||^2 -2\sum_{k=0}^N \langle f, \phi_k \rangle + \sum_{k=0}^N a_k^2 \langle \phi_k, \phi_k \rangle $$
# Then by taking the derivative
# $$\frac{\partial E}{\partial a_k} = \sum 2a_k \langle \phi_k, \phi_k \rangle - 2 \langle f, \phi_k \rangle = 0 \implies a_k = \frac{\langle f, \phi_k \rangle}{\langle \phi_k, \phi_k \rangle}$$
#
# ### Part d
# Use orthogonality

# %% [markdown]
# ## Question 3
# ![img](Images/IMG_6857.jpeg)

# %% [markdown]
# # Question 4
# ![Question](Images/IMG_6858.jpeg)
